# %% [markdown]
# <a href="https://colab.research.google.com/github/ArimaRX/codeptit/blob/main/colab/gym_recorder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install xvfb xserver-xephyr vnc4server python-opengl ffmpeg
# !pip3 install pyvirtualdisplay
# !pip3 install -U colabgymrender
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   aspell aspell-en dbus-user-session desktop-file-utils dictionaries-common
#   dosfstools eject emacsen-common enchant gdisk gnome-terminal
#   gnome-terminal-data gstreamer1.0-gl gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-pulseaudio gstreamer1.0-x gvfs
#   gvfs-common gvfs-daemons gvfs-libs hunspell-en-us libaa1 libaspell15
#   libatasmart4 libblockdev-crypto2 libblockdev-fs2 libblockdev-loop2
#   libblockdev-part-err2 libblockdev-part2 libblockdev-swap2 libblockdev-utils2
#   libblockdev2 libbrotli1 libcap2-bin libcdparanoia0 libdv4 libenchant1c2a
#   libgck-1-0 libgcr-base-3-1 libgpgme11 libgpm2 libgraphene-1.0-0
#   libgstreamer-gl1.0-0 libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgstreamer1.0-0 libhunspell-1.6-0
#   libhyphen0 libjavascriptcoregtk-4.0-18 libnautilus-extension1a libnotify4
#   libntfs-3g88 liborc-0.4-0 libpam-cap libparted-fs-resize0 libparted2
#   libsecret-1-0 libsecret-common libshout3 libtag1v5 libtag1v5-vanilla
#   libtext-iconv-perl libudisks2-0 libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libvolume-key1 libvte-2.91-0 libvte-2.91-common libwebkit2gtk-4.0-37
#   libwoff1 libxcb-xv0 libxxf86dga1 libyelp0 nautilus-extension-gnome-terminal
#   notification-daemon ntfs-3g parted udisks2 x11-apps x11-session-utils
#   x11-utils x11-xserver-utils xbase-clients xbitmaps xfonts-base
#   xfonts-encodings xfonts-utils xinit yelp yelp-xsl
# Suggested packages:
#   aspell-doc spellutils wordlist cdtool setcd gvfs-backends hunspell
#   openoffice.org-hunspell | openoffice.org-core libdv-bin oss-compat
#   libenchant-voikko gpm libvisual-0.4-plugins gstreamer1.0-tools libparted-dev
#   libparted-i18n libwebkit2gtk-4.0-37-gtk2 parted-doc libgle3 exfat-utils
#   btrfs-progs f2fs-tools mdadm libblockdev-mdraid2 nilfs-tools reiserfsprogs
#   xfsprogs udftools udisks2-btrfs udisks2-lvm2 vnc-java mesa-utils nickle
#   cairo-5c xorg-docs-core x11-xfs-utils
# The following NEW packages will be installed:
#   aspell aspell-en dbus-user-session desktop-file-utils dictionaries-common
#   dosfstools eject emacsen-common enchant gdisk gnome-terminal
#   gnome-terminal-data gstreamer1.0-gl gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-pulseaudio gstreamer1.0-x gvfs
#   gvfs-common gvfs-daemons gvfs-libs hunspell-en-us libaa1 libaspell15
#   libatasmart4 libblockdev-crypto2 libblockdev-fs2 libblockdev-loop2
#   libblockdev-part-err2 libblockdev-part2 libblockdev-swap2 libblockdev-utils2
#   libblockdev2 libbrotli1 libcap2-bin libcdparanoia0 libdv4 libenchant1c2a
#   libgck-1-0 libgcr-base-3-1 libgpgme11 libgpm2 libgraphene-1.0-0
#   libgstreamer-gl1.0-0 libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgstreamer1.0-0 libhunspell-1.6-0
#   libhyphen0 libjavascriptcoregtk-4.0-18 libnautilus-extension1a libnotify4
#   libntfs-3g88 liborc-0.4-0 libpam-cap libparted-fs-resize0 libparted2
#   libsecret-1-0 libsecret-common libshout3 libtag1v5 libtag1v5-vanilla
#   libtext-iconv-perl libudisks2-0 libv4l-0 libv4lconvert0 libvisual-0.4-0
#   libvolume-key1 libvte-2.91-0 libvte-2.91-common libwebkit2gtk-4.0-37
#   libwoff1 libxcb-xv0 libxxf86dga1 libyelp0 nautilus-extension-gnome-terminal
#   notification-daemon ntfs-3g parted python-opengl udisks2 vnc4server x11-apps
#   x11-session-utils x11-utils x11-xserver-utils xbase-clients xbitmaps
#   xfonts-base xfonts-encodings xfonts-utils xinit xserver-xephyr xvfb yelp
#   yelp-xsl
# 0 upgraded, 96 newly installed, 0 to remove and 49 not upgraded.
# Need to get 41.4 MB of archives.
# After this operation, 152 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libntfs-3g88 amd64 1:2017.3.23-2ubuntu0.18.04.4 [148 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ntfs-3g amd64 1:2017.3.23-2ubuntu0.18.04.4 [385 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 eject amd64 2.1.5+deb1+cvs20081104-13.2 [22.8 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcap2-bin amd64 1:2.25-1.2 [20.6 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpam-cap amd64 1:2.25-1.2 [7,268 B]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtext-iconv-perl amd64 1.7-5build6 [13.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 dosfstools amd64 4.1-1 [58.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libparted2 amd64 3.2-20ubuntu0.2 [123 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 parted amd64 3.2-20ubuntu0.2 [42.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libaspell15 amd64 0.60.7~20110707-4ubuntu0.2 [310 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 emacsen-common all 2.0.8 [17.6 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 dictionaries-common all 1.27.2 [186 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 aspell amd64 0.60.7~20110707-4ubuntu0.2 [87.7 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 aspell-en all 2017.08.24-0-0.1 [298 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 dbus-user-session amd64 1.12.2-1ubuntu1.3 [9,392 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 desktop-file-utils amd64 0.23-1ubuntu3.18.04.2 [51.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 hunspell-en-us all 1:2017.08.24 [168 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhunspell-1.6-0 amd64 1.6.2-1 [154 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 libenchant1c2a amd64 1.6.0-11.1 [64.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 enchant amd64 1.6.0-11.1 [12.2 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libvte-2.91-common all 0.52.2-1ubuntu1~18.04.2 [4,288 B]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libvte-2.91-0 amd64 0.52.2-1ubuntu1~18.04.2 [160 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gnome-terminal-data all 3.28.2-1ubuntu1~18.04.1 [32.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gnome-terminal amd64 3.28.2-1ubuntu1~18.04.1 [160 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgraphene-1.0-0 amd64 1.8.0-1 [37.4 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer1.0-0 amd64 1.14.5-0ubuntu1~18.04.2 [865 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/main amd64 liborc-0.4-0 amd64 1:0.4.28-1 [137 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.14.5-0ubuntu1~18.04.3 [689 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.14.5-0ubuntu1~18.04.3 [147 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-gl amd64 1.14.5-0ubuntu1~18.04.3 [84.0 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcdparanoia0 amd64 3.10.2+debian-13 [46.7 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvisual-0.4-0 amd64 0.4.0-11 [99.2 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-plugins-base amd64 1.14.5-0ubuntu1~18.04.3 [586 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgpm2 amd64 1.20.7-5 [15.1 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaa1 amd64 1.4p5-44build2 [47.2 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdv4 amd64 1.0.0-11 [57.8 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.14.5-0ubuntu1~18.04.2 [62.6 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 libshout3 amd64 2.4.1-2build1 [43.1 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-0.2build2 [265 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-0.2build2 [10.9 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libv4lconvert0 amd64 1.14.2-1 [76.1 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libv4l-0 amd64 1.14.2-1 [41.7 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-plugins-good amd64 1.14.5-0ubuntu1~18.04.2 [1,691 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-pulseaudio amd64 1.14.5-0ubuntu1~18.04.2 [86.4 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gstreamer1.0-x amd64 1.14.5-0ubuntu1~18.04.3 [74.3 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsecret-common all 0.18.6-1 [4,452 B]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsecret-1-0 amd64 0.18.6-1 [94.6 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudisks2-0 amd64 2.7.6-3ubuntu0.2 [98.1 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblockdev-part-err2 amd64 2.16-2 [4,892 B]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblockdev-utils2 amd64 2.16-2 [12.1 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/main amd64 gdisk amd64 1.0.3-1 [205 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblockdev-part2 amd64 2.16-2 [14.4 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblockdev-swap2 amd64 2.16-2 [6,616 B]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblockdev-loop2 amd64 2.16-2 [6,292 B]
# Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libparted-fs-resize0 amd64 3.2-20ubuntu0.2 [47.0 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblockdev-fs2 amd64 2.16-2 [18.8 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatasmart4 amd64 0.19-4 [23.7 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblockdev2 amd64 2.16-2 [39.0 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 udisks2 amd64 2.7.6-3ubuntu0.2 [231 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgck-1-0 amd64 3.28.0-1 [74.2 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgcr-base-3-1 amd64 3.28.0-1 [188 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gvfs-common all 1.36.1-0ubuntu1.3.3 [20.5 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gvfs-libs amd64 1.36.1-0ubuntu1.3.3 [96.0 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gvfs-daemons amd64 1.36.1-0ubuntu1.3.3 [117 kB]
# Get:67 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gvfs amd64 1.36.1-0ubuntu1.3.3 [111 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgpgme11 amd64 1.10.0-1ubuntu2 [111 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic/main amd64 libvolume-key1 amd64 0.3.9-4 [113 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic/main amd64 libblockdev-crypto2 amd64 2.16-2 [10.6 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbrotli1 amd64 1.0.3-1ubuntu1.3 [262 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic/main amd64 libhyphen0 amd64 2.8.8-5 [26.5 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libjavascriptcoregtk-4.0-18 amd64 2.32.4-0ubuntu0.18.04.1 [5,752 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libnautilus-extension1a amd64 1:3.26.4-0~ubuntu18.04.5 [15.1 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/main amd64 libnotify4 amd64 0.7.7-3 [17.3 kB]
# Get:76 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwoff1 amd64 1.0.2-1build0.1 [43.0 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libwebkit2gtk-4.0-37 amd64 2.32.4-0ubuntu0.18.04.1 [13.4 MB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-xv0 amd64 1.13-2~ubuntu18.04 [9,168 B]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/main amd64 libyelp0 amd64 3.26.0-1ubuntu2 [93.5 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 nautilus-extension-gnome-terminal amd64 3.28.2-1ubuntu1~18.04.1 [23.8 kB]
# Get:81 http://archive.ubuntu.com/ubuntu bionic/main amd64 notification-daemon amd64 3.20.0-3 [36.9 kB]
# Get:82 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Get:83 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-apps amd64 7.7+6ubuntu1 [653 kB]
# Get:84 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-session-utils amd64 7.7+2build1 [68.0 kB]
# Get:85 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-xserver-utils amd64 7.7+7build1 [159 kB]
# Get:86 http://archive.ubuntu.com/ubuntu bionic/main amd64 xinit amd64 1.3.4-3ubuntu3 [18.2 kB]
# Get:87 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xbase-clients all 1:7.7+19ubuntu7.1 [4,280 B]
# Get:88 http://archive.ubuntu.com/ubuntu bionic/universe amd64 vnc4server amd64 4.1.1+xorg4.3.0-37.3ubuntu2 [1,622 kB]
# Get:89 http://archive.ubuntu.com/ubuntu bionic/main amd64 xbitmaps all 1.1.1-2 [28.1 kB]
# Get:90 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-encodings all 1:1.0.4-2 [573 kB]
# Get:91 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:92 http://archive.ubuntu.com/ubuntu bionic/main amd64 xfonts-base all 1:1.0.4+nmu1 [5,914 kB]
# Get:93 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-xephyr amd64 2:1.19.6-1ubuntu4.11 [924 kB]
# Get:94 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.11 [785 kB]
# Get:95 http://archive.ubuntu.com/ubuntu bionic/main amd64 yelp-xsl all 3.20.1-4 [238 kB]
# Get:96 http://archive.ubuntu.com/ubuntu bionic/main amd64 yelp amd64 3.26.0-1ubuntu2 [514 kB]
# Fetched 41.4 MB in 5s (8,894 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 96.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libntfs-3g88.
# (Reading database ... 155653 files and directories currently installed.)
# Preparing to unpack .../00-libntfs-3g88_1%3a2017.3.23-2ubuntu0.18.04.4_amd64.deb ...
# Unpacking libntfs-3g88 (1:2017.3.23-2ubuntu0.18.04.4) ...
# Selecting previously unselected package ntfs-3g.
# Preparing to unpack .../01-ntfs-3g_1%3a2017.3.23-2ubuntu0.18.04.4_amd64.deb ...
# Unpacking ntfs-3g (1:2017.3.23-2ubuntu0.18.04.4) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../02-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package eject.
# Preparing to unpack .../03-eject_2.1.5+deb1+cvs20081104-13.2_amd64.deb ...
# Unpacking eject (2.1.5+deb1+cvs20081104-13.2) ...
# Selecting previously unselected package libcap2-bin.
# Preparing to unpack .../04-libcap2-bin_1%3a2.25-1.2_amd64.deb ...
# Unpacking libcap2-bin (1:2.25-1.2) ...
# Selecting previously unselected package libpam-cap:amd64.
# Preparing to unpack .../05-libpam-cap_1%3a2.25-1.2_amd64.deb ...
# Unpacking libpam-cap:amd64 (1:2.25-1.2) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../06-libtext-iconv-perl_1.7-5build6_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-5build6) ...
# Selecting previously unselected package dosfstools.
# Preparing to unpack .../07-dosfstools_4.1-1_amd64.deb ...
# Unpacking dosfstools (4.1-1) ...
# Selecting previously unselected package libparted2:amd64.
# Preparing to unpack .../08-libparted2_3.2-20ubuntu0.2_amd64.deb ...
# Unpacking libparted2:amd64 (3.2-20ubuntu0.2) ...
# Selecting previously unselected package parted.
# Preparing to unpack .../09-parted_3.2-20ubuntu0.2_amd64.deb ...
# Unpacking parted (3.2-20ubuntu0.2) ...
# Selecting previously unselected package libaspell15:amd64.
# Preparing to unpack .../10-libaspell15_0.60.7~20110707-4ubuntu0.2_amd64.deb ...
# Unpacking libaspell15:amd64 (0.60.7~20110707-4ubuntu0.2) ...
# Selecting previously unselected package emacsen-common.
# Preparing to unpack .../11-emacsen-common_2.0.8_all.deb ...
# Unpacking emacsen-common (2.0.8) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../12-dictionaries-common_1.27.2_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.27.2) ...
# Selecting previously unselected package aspell.
# Preparing to unpack .../13-aspell_0.60.7~20110707-4ubuntu0.2_amd64.deb ...
# Unpacking aspell (0.60.7~20110707-4ubuntu0.2) ...
# Selecting previously unselected package aspell-en.
# Preparing to unpack .../14-aspell-en_2017.08.24-0-0.1_all.deb ...
# Unpacking aspell-en (2017.08.24-0-0.1) ...
# Selecting previously unselected package dbus-user-session.
# Preparing to unpack .../15-dbus-user-session_1.12.2-1ubuntu1.3_amd64.deb ...
# Unpacking dbus-user-session (1.12.2-1ubuntu1.3) ...
# Selecting previously unselected package desktop-file-utils.
# Preparing to unpack .../16-desktop-file-utils_0.23-1ubuntu3.18.04.2_amd64.deb ...
# Unpacking desktop-file-utils (0.23-1ubuntu3.18.04.2) ...
# Selecting previously unselected package hunspell-en-us.
# Preparing to unpack .../17-hunspell-en-us_1%3a2017.08.24_all.deb ...
# Unpacking hunspell-en-us (1:2017.08.24) ...
# Selecting previously unselected package libhunspell-1.6-0:amd64.
# Preparing to unpack .../18-libhunspell-1.6-0_1.6.2-1_amd64.deb ...
# Unpacking libhunspell-1.6-0:amd64 (1.6.2-1) ...
# Selecting previously unselected package libenchant1c2a:amd64.
# Preparing to unpack .../19-libenchant1c2a_1.6.0-11.1_amd64.deb ...
# Unpacking libenchant1c2a:amd64 (1.6.0-11.1) ...
# Selecting previously unselected package enchant.
# Preparing to unpack .../20-enchant_1.6.0-11.1_amd64.deb ...
# Unpacking enchant (1.6.0-11.1) ...
# Selecting previously unselected package libvte-2.91-common.
# Preparing to unpack .../21-libvte-2.91-common_0.52.2-1ubuntu1~18.04.2_all.deb ...
# Unpacking libvte-2.91-common (0.52.2-1ubuntu1~18.04.2) ...
# Selecting previously unselected package libvte-2.91-0:amd64.
# Preparing to unpack .../22-libvte-2.91-0_0.52.2-1ubuntu1~18.04.2_amd64.deb ...
# Unpacking libvte-2.91-0:amd64 (0.52.2-1ubuntu1~18.04.2) ...
# Selecting previously unselected package gnome-terminal-data.
# Preparing to unpack .../23-gnome-terminal-data_3.28.2-1ubuntu1~18.04.1_all.deb ...
# Unpacking gnome-terminal-data (3.28.2-1ubuntu1~18.04.1) ...
# Selecting previously unselected package gnome-terminal.
# Preparing to unpack .../24-gnome-terminal_3.28.2-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking gnome-terminal (3.28.2-1ubuntu1~18.04.1) ...
# Selecting previously unselected package libgraphene-1.0-0:amd64.
# Preparing to unpack .../25-libgraphene-1.0-0_1.8.0-1_amd64.deb ...
# Unpacking libgraphene-1.0-0:amd64 (1.8.0-1) ...
# Selecting previously unselected package libgstreamer1.0-0:amd64.
# Preparing to unpack .../26-libgstreamer1.0-0_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package liborc-0.4-0:amd64.
# Preparing to unpack .../27-liborc-0.4-0_1%3a0.4.28-1_amd64.deb ...
# Unpacking liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Selecting previously unselected package libgstreamer-plugins-base1.0-0:amd64.
# Preparing to unpack .../28-libgstreamer-plugins-base1.0-0_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libgstreamer-gl1.0-0:amd64.
# Preparing to unpack .../29-libgstreamer-gl1.0-0_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking libgstreamer-gl1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package gstreamer1.0-gl:amd64.
# Preparing to unpack .../30-gstreamer1.0-gl_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking gstreamer1.0-gl:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libcdparanoia0:amd64.
# Preparing to unpack .../31-libcdparanoia0_3.10.2+debian-13_amd64.deb ...
# Unpacking libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Selecting previously unselected package libvisual-0.4-0:amd64.
# Preparing to unpack .../32-libvisual-0.4-0_0.4.0-11_amd64.deb ...
# Unpacking libvisual-0.4-0:amd64 (0.4.0-11) ...
# Selecting previously unselected package gstreamer1.0-plugins-base:amd64.
# Preparing to unpack .../33-gstreamer1.0-plugins-base_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libgpm2:amd64.
# Preparing to unpack .../34-libgpm2_1.20.7-5_amd64.deb ...
# Unpacking libgpm2:amd64 (1.20.7-5) ...
# Selecting previously unselected package libaa1:amd64.
# Preparing to unpack .../35-libaa1_1.4p5-44build2_amd64.deb ...
# Unpacking libaa1:amd64 (1.4p5-44build2) ...
# Selecting previously unselected package libdv4:amd64.
# Preparing to unpack .../36-libdv4_1.0.0-11_amd64.deb ...
# Unpacking libdv4:amd64 (1.0.0-11) ...
# Selecting previously unselected package libgstreamer-plugins-good1.0-0:amd64.
# Preparing to unpack .../37-libgstreamer-plugins-good1.0-0_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking libgstreamer-plugins-good1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package libshout3:amd64.
# Preparing to unpack .../38-libshout3_2.4.1-2build1_amd64.deb ...
# Unpacking libshout3:amd64 (2.4.1-2build1) ...
# Selecting previously unselected package libtag1v5-vanilla:amd64.
# Preparing to unpack .../39-libtag1v5-vanilla_1.11.1+dfsg.1-0.2build2_amd64.deb ...
# Unpacking libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.2build2) ...
# Selecting previously unselected package libtag1v5:amd64.
# Preparing to unpack .../40-libtag1v5_1.11.1+dfsg.1-0.2build2_amd64.deb ...
# Unpacking libtag1v5:amd64 (1.11.1+dfsg.1-0.2build2) ...
# Selecting previously unselected package libv4lconvert0:amd64.
# Preparing to unpack .../41-libv4lconvert0_1.14.2-1_amd64.deb ...
# Unpacking libv4lconvert0:amd64 (1.14.2-1) ...
# Selecting previously unselected package libv4l-0:amd64.
# Preparing to unpack .../42-libv4l-0_1.14.2-1_amd64.deb ...
# Unpacking libv4l-0:amd64 (1.14.2-1) ...
# Selecting previously unselected package gstreamer1.0-plugins-good:amd64.
# Preparing to unpack .../43-gstreamer1.0-plugins-good_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking gstreamer1.0-plugins-good:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package gstreamer1.0-pulseaudio:amd64.
# Preparing to unpack .../44-gstreamer1.0-pulseaudio_1.14.5-0ubuntu1~18.04.2_amd64.deb ...
# Unpacking gstreamer1.0-pulseaudio:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Selecting previously unselected package gstreamer1.0-x:amd64.
# Preparing to unpack .../45-gstreamer1.0-x_1.14.5-0ubuntu1~18.04.3_amd64.deb ...
# Unpacking gstreamer1.0-x:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Selecting previously unselected package libsecret-common.
# Preparing to unpack .../46-libsecret-common_0.18.6-1_all.deb ...
# Unpacking libsecret-common (0.18.6-1) ...
# Selecting previously unselected package libsecret-1-0:amd64.
# Preparing to unpack .../47-libsecret-1-0_0.18.6-1_amd64.deb ...
# Unpacking libsecret-1-0:amd64 (0.18.6-1) ...
# Selecting previously unselected package libudisks2-0:amd64.
# Preparing to unpack .../48-libudisks2-0_2.7.6-3ubuntu0.2_amd64.deb ...
# Unpacking libudisks2-0:amd64 (2.7.6-3ubuntu0.2) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../49-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Selecting previously unselected package libblockdev-part-err2:amd64.
# Preparing to unpack .../50-libblockdev-part-err2_2.16-2_amd64.deb ...
# Unpacking libblockdev-part-err2:amd64 (2.16-2) ...
# Selecting previously unselected package libblockdev-utils2:amd64.
# Preparing to unpack .../51-libblockdev-utils2_2.16-2_amd64.deb ...
# Unpacking libblockdev-utils2:amd64 (2.16-2) ...
# Selecting previously unselected package gdisk.
# Preparing to unpack .../52-gdisk_1.0.3-1_amd64.deb ...
# Unpacking gdisk (1.0.3-1) ...
# Selecting previously unselected package libblockdev-part2:amd64.
# Preparing to unpack .../53-libblockdev-part2_2.16-2_amd64.deb ...
# Unpacking libblockdev-part2:amd64 (2.16-2) ...
# Selecting previously unselected package libblockdev-swap2:amd64.
# Preparing to unpack .../54-libblockdev-swap2_2.16-2_amd64.deb ...
# Unpacking libblockdev-swap2:amd64 (2.16-2) ...
# Selecting previously unselected package libblockdev-loop2:amd64.
# Preparing to unpack .../55-libblockdev-loop2_2.16-2_amd64.deb ...
# Unpacking libblockdev-loop2:amd64 (2.16-2) ...
# Selecting previously unselected package libparted-fs-resize0:amd64.
# Preparing to unpack .../56-libparted-fs-resize0_3.2-20ubuntu0.2_amd64.deb ...
# Unpacking libparted-fs-resize0:amd64 (3.2-20ubuntu0.2) ...
# Selecting previously unselected package libblockdev-fs2:amd64.
# Preparing to unpack .../57-libblockdev-fs2_2.16-2_amd64.deb ...
# Unpacking libblockdev-fs2:amd64 (2.16-2) ...
# Selecting previously unselected package libatasmart4:amd64.
# Preparing to unpack .../58-libatasmart4_0.19-4_amd64.deb ...
# Unpacking libatasmart4:amd64 (0.19-4) ...
# Selecting previously unselected package libblockdev2:amd64.
# Preparing to unpack .../59-libblockdev2_2.16-2_amd64.deb ...
# Unpacking libblockdev2:amd64 (2.16-2) ...
# Selecting previously unselected package udisks2.
# Preparing to unpack .../60-udisks2_2.7.6-3ubuntu0.2_amd64.deb ...
# Unpacking udisks2 (2.7.6-3ubuntu0.2) ...
# Selecting previously unselected package libgck-1-0:amd64.
# Preparing to unpack .../61-libgck-1-0_3.28.0-1_amd64.deb ...
# Unpacking libgck-1-0:amd64 (3.28.0-1) ...
# Selecting previously unselected package libgcr-base-3-1:amd64.
# Preparing to unpack .../62-libgcr-base-3-1_3.28.0-1_amd64.deb ...
# Unpacking libgcr-base-3-1:amd64 (3.28.0-1) ...
# Selecting previously unselected package gvfs-common.
# Preparing to unpack .../63-gvfs-common_1.36.1-0ubuntu1.3.3_all.deb ...
# Unpacking gvfs-common (1.36.1-0ubuntu1.3.3) ...
# Selecting previously unselected package gvfs-libs:amd64.
# Preparing to unpack .../64-gvfs-libs_1.36.1-0ubuntu1.3.3_amd64.deb ...
# Unpacking gvfs-libs:amd64 (1.36.1-0ubuntu1.3.3) ...
# Selecting previously unselected package gvfs-daemons.
# Preparing to unpack .../65-gvfs-daemons_1.36.1-0ubuntu1.3.3_amd64.deb ...
# Unpacking gvfs-daemons (1.36.1-0ubuntu1.3.3) ...
# Selecting previously unselected package gvfs:amd64.
# Preparing to unpack .../66-gvfs_1.36.1-0ubuntu1.3.3_amd64.deb ...
# Unpacking gvfs:amd64 (1.36.1-0ubuntu1.3.3) ...
# Selecting previously unselected package libgpgme11:amd64.
# Preparing to unpack .../67-libgpgme11_1.10.0-1ubuntu2_amd64.deb ...
# Unpacking libgpgme11:amd64 (1.10.0-1ubuntu2) ...
# Selecting previously unselected package libvolume-key1.
# Preparing to unpack .../68-libvolume-key1_0.3.9-4_amd64.deb ...
# Unpacking libvolume-key1 (0.3.9-4) ...
# Selecting previously unselected package libblockdev-crypto2:amd64.
# Preparing to unpack .../69-libblockdev-crypto2_2.16-2_amd64.deb ...
# Unpacking libblockdev-crypto2:amd64 (2.16-2) ...
# Selecting previously unselected package libbrotli1:amd64.
# Preparing to unpack .../70-libbrotli1_1.0.3-1ubuntu1.3_amd64.deb ...
# Unpacking libbrotli1:amd64 (1.0.3-1ubuntu1.3) ...
# Selecting previously unselected package libhyphen0:amd64.
# Preparing to unpack .../71-libhyphen0_2.8.8-5_amd64.deb ...
# Unpacking libhyphen0:amd64 (2.8.8-5) ...
# Selecting previously unselected package libjavascriptcoregtk-4.0-18:amd64.
# Preparing to unpack .../72-libjavascriptcoregtk-4.0-18_2.32.4-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libjavascriptcoregtk-4.0-18:amd64 (2.32.4-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libnautilus-extension1a:amd64.
# Preparing to unpack .../73-libnautilus-extension1a_1%3a3.26.4-0~ubuntu18.04.5_amd64.deb ...
# Unpacking libnautilus-extension1a:amd64 (1:3.26.4-0~ubuntu18.04.5) ...
# Selecting previously unselected package libnotify4:amd64.
# Preparing to unpack .../74-libnotify4_0.7.7-3_amd64.deb ...
# Unpacking libnotify4:amd64 (0.7.7-3) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../75-libwoff1_1.0.2-1build0.1_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build0.1) ...
# Selecting previously unselected package libwebkit2gtk-4.0-37:amd64.
# Preparing to unpack .../76-libwebkit2gtk-4.0-37_2.32.4-0ubuntu0.18.04.1_amd64.deb ...
# Unpacking libwebkit2gtk-4.0-37:amd64 (2.32.4-0ubuntu0.18.04.1) ...
# Selecting previously unselected package libxcb-xv0:amd64.
# Preparing to unpack .../77-libxcb-xv0_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-xv0:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libyelp0:amd64.
# Preparing to unpack .../78-libyelp0_3.26.0-1ubuntu2_amd64.deb ...
# Unpacking libyelp0:amd64 (3.26.0-1ubuntu2) ...
# Selecting previously unselected package nautilus-extension-gnome-terminal.
# Preparing to unpack .../79-nautilus-extension-gnome-terminal_3.28.2-1ubuntu1~18.04.1_amd64.deb ...
# Unpacking nautilus-extension-gnome-terminal (3.28.2-1ubuntu1~18.04.1) ...
# Selecting previously unselected package notification-daemon.
# Preparing to unpack .../80-notification-daemon_3.20.0-3_amd64.deb ...
# Unpacking notification-daemon (3.20.0-3) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../81-python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Selecting previously unselected package x11-apps.
# Preparing to unpack .../82-x11-apps_7.7+6ubuntu1_amd64.deb ...
# Unpacking x11-apps (7.7+6ubuntu1) ...
# Selecting previously unselected package x11-session-utils.
# Preparing to unpack .../83-x11-session-utils_7.7+2build1_amd64.deb ...
# Unpacking x11-session-utils (7.7+2build1) ...
# Selecting previously unselected package x11-xserver-utils.
# Preparing to unpack .../84-x11-xserver-utils_7.7+7build1_amd64.deb ...
# Unpacking x11-xserver-utils (7.7+7build1) ...
# Selecting previously unselected package xinit.
# Preparing to unpack .../85-xinit_1.3.4-3ubuntu3_amd64.deb ...
# Unpacking xinit (1.3.4-3ubuntu3) ...
# Selecting previously unselected package xbase-clients.
# Preparing to unpack .../86-xbase-clients_1%3a7.7+19ubuntu7.1_all.deb ...
# Unpacking xbase-clients (1:7.7+19ubuntu7.1) ...
# Selecting previously unselected package vnc4server.
# Preparing to unpack .../87-vnc4server_4.1.1+xorg4.3.0-37.3ubuntu2_amd64.deb ...
# Unpacking vnc4server (4.1.1+xorg4.3.0-37.3ubuntu2) ...
# Selecting previously unselected package xbitmaps.
# Preparing to unpack .../88-xbitmaps_1.1.1-2_all.deb ...
# Unpacking xbitmaps (1.1.1-2) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../89-xfonts-encodings_1%3a1.0.4-2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.4-2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../90-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../91-xfonts-base_1%3a1.0.4+nmu1_all.deb ...
# Unpacking xfonts-base (1:1.0.4+nmu1) ...
# Selecting previously unselected package xserver-xephyr.
# Preparing to unpack .../92-xserver-xephyr_2%3a1.19.6-1ubuntu4.11_amd64.deb ...
# Unpacking xserver-xephyr (2:1.19.6-1ubuntu4.11) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../93-xvfb_2%3a1.19.6-1ubuntu4.11_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.11) ...
# Selecting previously unselected package yelp-xsl.
# Preparing to unpack .../94-yelp-xsl_3.20.1-4_all.deb ...
# Unpacking yelp-xsl (3.20.1-4) ...
# Selecting previously unselected package yelp.
# Preparing to unpack .../95-yelp_3.26.0-1ubuntu2_amd64.deb ...
# Unpacking yelp (3.26.0-1ubuntu2) ...
# Setting up libbrotli1:amd64 (1.0.3-1ubuntu1.3) ...
# Setting up libnotify4:amd64 (0.7.7-3) ...
# Setting up libsecret-common (0.18.6-1) ...
# Setting up libatasmart4:amd64 (0.19-4) ...
# Setting up libparted2:amd64 (3.2-20ubuntu0.2) ...
# Setting up libblockdev-utils2:amd64 (2.16-2) ...
# Setting up libpam-cap:amd64 (1:2.25-1.2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up x11-session-utils (7.7+2build1) ...
# Setting up dosfstools (4.1-1) ...
# Setting up libparted-fs-resize0:amd64 (3.2-20ubuntu0.2) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Setting up libwoff1:amd64 (1.0.2-1build0.1) ...
# Setting up desktop-file-utils (0.23-1ubuntu3.18.04.2) ...
# Setting up xinit (1.3.4-3ubuntu3) ...
# Setting up libhunspell-1.6-0:amd64 (1.6.2-1) ...
# Setting up libgpm2:amd64 (1.20.7-5) ...
# Setting up libaspell15:amd64 (0.60.7~20110707-4ubuntu0.2) ...
# Setting up xbitmaps (1.1.1-2) ...
# Setting up libcap2-bin (1:2.25-1.2) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.11) ...
# Setting up libblockdev-part-err2:amd64 (2.16-2) ...
# Setting up libblockdev-fs2:amd64 (2.16-2) ...
# Setting up libv4lconvert0:amd64 (1.14.2-1) ...
# Setting up emacsen-common (2.0.8) ...
# Setting up libudisks2-0:amd64 (2.7.6-3ubuntu0.2) ...
# Setting up gnome-terminal-data (3.28.2-1ubuntu1~18.04.1) ...
# Setting up libblockdev2:amd64 (2.16-2) ...
# Setting up parted (3.2-20ubuntu0.2) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-13) ...
# Setting up libblockdev-loop2:amd64 (2.16-2) ...
# Setting up libblockdev-swap2:amd64 (2.16-2) ...
# Setting up xfonts-encodings (1:1.0.4-2) ...
# Setting up dbus-user-session (1.12.2-1ubuntu1.3) ...
# Setting up libgck-1-0:amd64 (3.28.0-1) ...
# Setting up libgpgme11:amd64 (1.10.0-1ubuntu2) ...
# Setting up libhyphen0:amd64 (2.8.8-5) ...
# Setting up libvte-2.91-common (0.52.2-1ubuntu1~18.04.2) ...
# Setting up libaa1:amd64 (1.4p5-44build2) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up libtext-iconv-perl (1.7-5build6) ...
# Setting up libxcb-xv0:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libnautilus-extension1a:amd64 (1:3.26.4-0~ubuntu18.04.5) ...
# Setting up gdisk (1.0.3-1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-11) ...
# Setting up x11-xserver-utils (7.7+7build1) ...
# Setting up libjavascriptcoregtk-4.0-18:amd64 (2.32.4-0ubuntu0.18.04.1) ...
# Setting up yelp-xsl (3.20.1-4) ...
# Setting up libntfs-3g88 (1:2017.3.23-2ubuntu0.18.04.4) ...
# Setting up libgraphene-1.0-0:amd64 (1.8.0-1) ...
# Setting up x11-apps (7.7+6ubuntu1) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.28-1) ...
# Setting up libblockdev-part2:amd64 (2.16-2) ...
# Setting up libshout3:amd64 (2.4.1-2build1) ...
# Setting up libsecret-1-0:amd64 (0.18.6-1) ...
# Setting up libdv4:amd64 (1.0.0-11) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.2build2) ...
# Setting up notification-daemon (3.20.0-3) ...
# Setting up eject (2.1.5+deb1+cvs20081104-13.2) ...
# Setting up libvolume-key1 (0.3.9-4) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-0.2build2) ...
# Setting up libgstreamer1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up libgcr-base-3-1:amd64 (3.28.0-1) ...
# Setting up gvfs-common (1.36.1-0ubuntu1.3.3) ...
# Setting up libv4l-0:amd64 (1.14.2-1) ...
# Setting up dictionaries-common (1.27.2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up libvte-2.91-0:amd64 (0.52.2-1ubuntu1~18.04.2) ...
# Setting up x11-utils (7.7+3build1) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up udisks2 (2.7.6-3ubuntu0.2) ...
# Created symlink /etc/systemd/system/graphical.target.wants/udisks2.service → /lib/systemd/system/udisks2.service.
# Setting up xserver-xephyr (2:1.19.6-1ubuntu4.11) ...
# Setting up libblockdev-crypto2:amd64 (2.16-2) ...
# Setting up gnome-terminal (3.28.2-1ubuntu1~18.04.1) ...
# update-alternatives: using /usr/bin/gnome-terminal.wrapper to provide /usr/bin/x-terminal-emulator (x-terminal-emulator) in auto mode
# Setting up gvfs-libs:amd64 (1.36.1-0ubuntu1.3.3) ...
# Setting up ntfs-3g (1:2017.3.23-2ubuntu0.18.04.4) ...
# Setting up aspell (0.60.7~20110707-4ubuntu0.2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up hunspell-en-us (1:2017.08.24) ...
# Setting up xfonts-base (1:1.0.4+nmu1) ...
# Setting up libenchant1c2a:amd64 (1.6.0-11.1) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up gvfs-daemons (1.36.1-0ubuntu1.3.3) ...
# Setting up gstreamer1.0-pulseaudio:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up xbase-clients (1:7.7+19ubuntu7.1) ...
# Setting up gstreamer1.0-gl:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up gvfs:amd64 (1.36.1-0ubuntu1.3.3) ...
# Setting up vnc4server (4.1.1+xorg4.3.0-37.3ubuntu2) ...
# update-alternatives: using /usr/bin/vnc4server to provide /usr/bin/vncserver (vncserver) in auto mode
# update-alternatives: using /usr/bin/Xvnc4 to provide /usr/bin/Xvnc (Xvnc) in auto mode
# update-alternatives: using /usr/bin/x0vnc4server to provide /usr/bin/x0vncserver (x0vncserver) in auto mode
# update-alternatives: using /usr/bin/vnc4passwd to provide /usr/bin/vncpasswd (vncpasswd) in auto mode
# update-alternatives: using /usr/bin/vnc4config to provide /usr/bin/vncconfig (vncconfig) in auto mode
# Setting up aspell-en (2017.08.24-0-0.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# Setting up enchant (1.6.0-11.1) ...
# Setting up gstreamer1.0-x:amd64 (1.14.5-0ubuntu1~18.04.3) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up libwebkit2gtk-4.0-37:amd64 (2.32.4-0ubuntu0.18.04.1) ...
# Setting up libyelp0:amd64 (3.26.0-1ubuntu2) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.14.5-0ubuntu1~18.04.2) ...
# Setting up yelp (3.26.0-1ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libglib2.0-0:amd64 (2.56.4-0ubuntu0.18.04.9) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for dbus (1.12.2-1ubuntu1.3) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Setting up nautilus-extension-gnome-terminal (3.28.2-1ubuntu1~18.04.1) ...
# Processing triggers for dictionaries-common (1.27.2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76.)
# debconf: falling back to frontend: Readline
# aspell-autobuildhash: processing: en [en-common].
# aspell-autobuildhash: processing: en [en-variant_0].
# aspell-autobuildhash: processing: en [en-variant_1].
# aspell-autobuildhash: processing: en [en-variant_2].
# aspell-autobuildhash: processing: en [en-w_accents-only].
# aspell-autobuildhash: processing: en [en-wo_accents-only].
# aspell-autobuildhash: processing: en [en_AU-variant_0].
# aspell-autobuildhash: processing: en [en_AU-variant_1].
# aspell-autobuildhash: processing: en [en_AU-w_accents-only].
# aspell-autobuildhash: processing: en [en_AU-wo_accents-only].
# aspell-autobuildhash: processing: en [en_CA-variant_0].
# aspell-autobuildhash: processing: en [en_CA-variant_1].
# aspell-autobuildhash: processing: en [en_CA-w_accents-only].
# aspell-autobuildhash: processing: en [en_CA-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ise-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-w_accents-only].
# aspell-autobuildhash: processing: en [en_GB-ize-wo_accents-only].
# aspell-autobuildhash: processing: en [en_GB-variant_0].
# aspell-autobuildhash: processing: en [en_GB-variant_1].
# aspell-autobuildhash: processing: en [en_US-w_accents-only].
# aspell-autobuildhash: processing: en [en_US-wo_accents-only].
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting colabgymrender
#   Downloading colabgymrender-1.1.0.tar.gz (3.5 kB)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.7/dist-packages (from colabgymrender) (0.2.3.5)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (4.64.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (1.21.6)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from moviepy->colabgymrender) (2.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio<3.0,>=2.1.2->moviepy->colabgymrender) (7.1.2)
# Building wheels for collected packages: colabgymrender
#   Building wheel for colabgymrender (setup.py) ... done
#   Created wheel for colabgymrender: filename=colabgymrender-1.1.0-py3-none-any.whl size=3132 sha256=df5acb918e6372995de9c10ce140be71ab0aa181cf1b1ae2114a5148f41b6834
#   Stored in directory: /root/.cache/pip/wheels/f1/0a/2a/86955ea711b461ab7918236fed2568733f75ed677d0524b56c
# Successfully built colabgymrender
# Installing collected packages: colabgymrender
# Successfully installed colabgymrender-1.1.0

# %%
import gym
from colabgymrender.recorder import Recorder
from pyvirtualdisplay import Display
display = Display(visible=0, size=(400, 300))
display.start();
env = gym.make('MountainCar-v0')
env = Recorder(env, './video', fps=60)
env.reset()
done = False
while not done:
    action = 2
    new_state, reward, done, _ = env.step(action)
env.play()
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# <video controls>
#  <source src="...
